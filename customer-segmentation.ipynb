# %%
import pandas as pd
import matplotlib.pyplot as plt
import numpy as np
import seaborn as sns

# %%
# %matplotlib inline

# %%
df=pd.read_csv("Mall_Customers.csv")
df
# Out:
#      CustomerID  Gender  Age  Annual Income (k$)  Spending Score (1-100)
# 0             1    Male   19                  15                      39
# 1             2    Male   21                  15                      81
# 2             3  Female   20                  16                       6
# 3             4  Female   23                  16                      77
# 4             5  Female   31                  17                      40
# ..          ...     ...  ...                 ...                     ...
# 195         196  Female   35                 120                      79
# 196         197  Female   45                 126                      28
# 197         198    Male   32                 126                      74
# 198         199    Male   32                 137                      18
# 199         200    Male   30                 137                      83
#
# [200 rows x 5 columns]

# %%
df.info()
# Out:
# <class 'pandas.core.frame.DataFrame'>
# RangeIndex: 200 entries, 0 to 199
# Data columns (total 5 columns):
#  #   Column                  Non-Null Count  Dtype
# ---  ------                  --------------  -----
#  0   CustomerID              200 non-null    int64
#  1   Gender                  200 non-null    object
#  2   Age                     200 non-null    int64
#  3   Annual Income (k$)      200 non-null    int64
#  4   Spending Score (1-100)  200 non-null    int64
# dtypes: int64(4), object(1)
# memory usage: 7.9+ KB

# %%
df.describe()
# Out:
#        CustomerID         Age  Annual Income (k$)  Spending Score (1-100)
# count  200.000000  200.000000          200.000000              200.000000
# mean   100.500000   38.850000           60.560000               50.200000
# std     57.879185   13.969007           26.264721               25.823522
# min      1.000000   18.000000           15.000000                1.000000
# 25%     50.750000   28.750000           41.500000               34.750000
# 50%    100.500000   36.000000           61.500000               50.000000
# 75%    150.250000   49.000000           78.000000               73.000000
# max    200.000000   70.000000          137.000000               99.000000

# %%
df.dtypes
# Out:
# CustomerID                 int64
# Gender                    object
# Age                        int64
# Annual Income (k$)         int64
# Spending Score (1-100)     int64
# dtype: object

# %%
df.isnull().sum()
# Out:
# CustomerID                0
# Gender                    0
# Age                       0
# Annual Income (k$)        0
# Spending Score (1-100)    0
# dtype: int64

# %%
plt.figure(1,figsize=(15,6))
c=0
for i in ['Age','Annual Income (k$)','Spending Score (1-100)']:
    c+=1
    plt.subplot(1,3,c)
    plt.subplots_adjust(wspace=0.5)
    sns.distplot(df[i])
    
plt.show()
# Out:
# C:\Users\janak\anaconda3\lib\site-packages\seaborn\distributions.py:2557: FutureWarning: `distplot` is a deprecated function and will be removed in a future version. Please adapt your code to use either `displot` (a figure-level function with similar flexibility) or `histplot` (an axes-level function for histograms).
#   warnings.warn(msg, FutureWarning)
# C:\Users\janak\anaconda3\lib\site-packages\seaborn\distributions.py:2557: FutureWarning: `distplot` is a deprecated function and will be removed in a future version. Please adapt your code to use either `displot` (a figure-level function with similar flexibility) or `histplot` (an axes-level function for histograms).
#   warnings.warn(msg, FutureWarning)
# ...

# %%
plt.figure(figsize=(15,5))
sns.countplot(y='Gender',data=df)
plt.show()

# %%
df18_25=df[['CustomerID','Age']][(df['Age']>=18) & (df['Age']<=25)]
df26_35=df[['CustomerID','Age']][(df['Age']>=26) & (df['Age']<=35)]
df36_45=df[['CustomerID','Age']][(df['Age']>=36) & (df['Age']<=45)]
df46_55=df[['CustomerID','Age']][(df['Age']>=46) & (df['Age']<=55)]
df56a=df[['CustomerID','Age']][(df['Age']>=56)]
x=['18_25','26_35','36_45','46_55','56+']
y=[len(df18_25.values),len(df26_35.values),len(df36_45.values),len(df46_55.values),len(df56a.values)]
plt.figure(figsize=(15,6))
sns.barplot(x=x,y=y,data=df)
plt.xlabel('Age Group')
plt.show()

# %%
sns.relplot(x="Annual Income (k$)",y="Spending Score (1-100)",data=df)

# %%
df1_20=df['Spending Score (1-100)'][(df['Spending Score (1-100)']>=1) & (df['Spending Score (1-100)']<=20)]
df21_40=df['Spending Score (1-100)'][(df['Spending Score (1-100)']>=21) & (df['Spending Score (1-100)']<=40)]
df41_60=df['Spending Score (1-100)'][(df['Spending Score (1-100)']>=41) & (df['Spending Score (1-100)']<=60)]
df61_80=df['Spending Score (1-100)'][(df['Spending Score (1-100)']>=61) & (df['Spending Score (1-100)']<=80)]
df81above=df['Spending Score (1-100)'][(df['Spending Score (1-100)']>=81)]

# %%
X=['1 to 20','21 to 40','41 to 60','61 to 80','81+']
Y=[len(df1_20.values),len(df21_40.values),len(df41_60.values),len(df61_80.values),len(df81above.values)]
plt.figure(figsize=(15,6))
sns.barplot(x=X,y=Y,data=df)
plt.xlabel('Spending Score')
plt.show()

# %%
df0_30=df['Annual Income (k$)'][(df['Annual Income (k$)']>=0) & (df['Annual Income (k$)']<=30)]
df31_60=df['Annual Income (k$)'][(df['Annual Income (k$)']>=31) & (df['Annual Income (k$)']<=60)]
df61_90=df['Annual Income (k$)'][(df['Annual Income (k$)']>=61) & (df['Annual Income (k$)']<=90)]
df91_120=df['Annual Income (k$)'][(df['Annual Income (k$)']>=91) & (df['Annual Income (k$)']<=120)]
df120above=df['Annual Income (k$)'][(df['Annual Income (k$)']>=121)]

# %%
X=['0-30','31-60','61-90','91-120','120+']
Y=[len(df0_30.values),len(df31_60.values),len(df61_90.values),len(df91_120.values),len(df120above.values)]
plt.figure(figsize=(15,6))
sns.barplot(x=X,y=Y)
plt.xlabel('Annual Income (k$)')
plt.show()

# %%
X1=df[['Age','Spending Score (1-100)']].values
from sklearn.cluster import KMeans
clusters=[]
for k in range(1,11):
    kmeans=KMeans(n_clusters=k)
    kmeans.fit(X1)
    clusters.append(kmeans.inertia_)
plt.figure(figsize=(15,6))
plt.plot(range(1,11),clusters,marker='o',color='red')
plt.show()
# Out:
# C:\Users\janak\anaconda3\lib\site-packages\sklearn\cluster\_kmeans.py:881: UserWarning: KMeans is known to have a memory leak on Windows with MKL, when there are less chunks than available threads. You can avoid it by setting the environment variable OMP_NUM_THREADS=1.
#   warnings.warn(
# range(1, 11)

# %%
kmeans=KMeans(n_clusters=4)
label=kmeans.fit_predict(X1)

# %%
plt.scatter(X1[:,0],X1[:,1],c=kmeans.labels_)
plt.scatter(kmeans.cluster_centers_[:,0],kmeans.cluster_centers_[:,1],color='black')
plt.show()

# %%
X2=df[['Annual Income (k$)','Spending Score (1-100)']].values
from sklearn.cluster import KMeans
clusters=[]
for k in range(1,11):
    kmeans=KMeans(n_clusters=k)
    kmeans.fit(X2)
    clusters.append(kmeans.inertia_)
plt.figure(figsize=(15,6))
plt.plot(range(1,11),clusters,marker='o',color='red')
plt.show()
# Out:
# C:\Users\janak\anaconda3\lib\site-packages\sklearn\cluster\_kmeans.py:881: UserWarning: KMeans is known to have a memory leak on Windows with MKL, when there are less chunks than available threads. You can avoid it by setting the environment variable OMP_NUM_THREADS=1.
#   warnings.warn(

# %%
kmean=KMeans(n_clusters=5)
label=kmean.fit_predict(X2)

# %%
plt.scatter(X2[:,0],X1[:,1],c=kmean.labels_,cmap="rainbow")
plt.scatter(kmean.cluster_centers_[:,0],kmean.cluster_centers_[:,1],color='black')
plt.show()

# %%
X3=df.iloc[:,2:].values
from sklearn.cluster import KMeans
clusters=[]
for k in range(1,11):
    kmeans=KMeans(n_clusters=k)
    kmeans.fit(X3)
    clusters.append(kmeans.inertia_)
plt.figure(figsize=(15,6))
plt.plot(range(1,11),clusters,marker='o',color='red')
plt.show()
# Out:
# C:\Users\janak\anaconda3\lib\site-packages\sklearn\cluster\_kmeans.py:881: UserWarning: KMeans is known to have a memory leak on Windows with MKL, when there are less chunks than available threads. You can avoid it by setting the environment variable OMP_NUM_THREADS=1.
#   warnings.warn(

# %%
kmeanss=KMeans(n_clusters=6)

# %%
clusters=kmean.fit_predict(X3)
from mpl_toolkits.mplot3d import Axes3D
df["label"]=clusters

# %%
fig=plt.figure(figsize=(15,6))
ax=fig.add_subplot(111,projection='3d')
ax.scatter(df['Age'][df['label']==0],df['Spending Score (1-100)'][df['label']==0],df['Annual Income (k$)'][df['label']==0],c="red")
ax.scatter(df['Age'][df['label']==1],df['Spending Score (1-100)'][df['label']==1],df['Annual Income (k$)'][df['label']==1],c="blue")
ax.scatter(df['Age'][df['label']==2],df['Spending Score (1-100)'][df['label']==2],df['Annual Income (k$)'][df['label']==2],c="orange")
ax.scatter(df['Age'][df['label']==3],df['Spending Score (1-100)'][df['label']==3],df['Annual Income (k$)'][df['label']==3],c="yellow")
ax.scatter(df['Age'][df['label']==4],df['Spending Score (1-100)'][df['label']==4],df['Annual Income (k$)'][df['label']==4],c="green")
plt.xlabel('Age')
plt.ylabel('Spending Score')
ax.set_zlabel('Annual Income')
# Out:
# Text(0.5, 0, 'Annual Income')
